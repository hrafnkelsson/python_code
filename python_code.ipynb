# %% [markdown]
# <a href="https://colab.research.google.com/github/hrafnkelsson/python_code/blob/main/python_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  pip install sympy
from sympy import *
init_printing()
#x, y, z, t = symbols('x y z t')
#k, m, n = symbols('k m n', integer=True)
#f, g, h = symbols('f g h', cls=Function)
#x = Symbol('x')
#limit(sin(x)/x, x, 0)
#integrate(1/x, x)
#a = Symbol('a')
#x, y, z, w = symbols('x y z w')
#linsolve(Matrix(( [(1 + 10*a - 20*a**2 + 15*a**3 - 4*a**4), (1-a)*(1 + 10*a - 40*a**2 + 45*a**3 - 16*a**4),  (1-a)**2*(1 + 10*a - 80*a**2 + 135*a**3 - 64*a**4), (1-a)**3* (1 + 10*a - 160*a**2 + 405*a**3 - 256*a**4), -(4 - 6*a + 4*a**2 - a**3 )], [ (-3 - 10*a + 10*a**2 - 3*a**3),  (1-a)*(-1 - 10*a + 20*a**2 - 9*a**3), (1-a)**2*(3 - 10*a + 40*a**2 - 27*a**3), (1-a)**3*(11 - 10*a + 80*a**2 - 81*a**3), -(-6 + 4*a - a**2)], [(3 + 5*a - 2*a**2), (1-a)*(-1 + 5*a - 4*a**2), (1-a)**2*(-3 + 5*a - 8*a**2), (1-a)**3*(11 + 5*a - 16*a**2), -(4 - a)], [(-1 - a),  (1-a)*(1 - a), (1-a)**2*(-1 - a), (1-a)**3*(1 - a), -(-1)])), (x, y, z, w))
#a, b = symbols('a b')
#M = Matrix([[1, 2, 3], [4, 5, 6],[7, 8, 9]])
#M**2
#Q = Matrix([[1, -2*a*cos(b), a**2], [-2*a*cos(b), 1 + 4*(a*cos(b))**2, -2*a*cos(b) -2*a**3*cos(b)],[a**2, -2*a*cos(b) -2*a**3*cos(b), 1 + 4*(a*cos(b))**2 +a**4]])
#Q = (1 + a**2)*(1/(1 - a**2))*(1/(1 + 2*a**2 + a**4 - 4*a**2*cos(b)))*Q
#Q**-1
#Q2 = Matrix([[1, -2*a*cos(b)], [-2*a*cos(b), 1 + 4*(a*cos(b))**2]])
#Q2 = (1 + a**2)*(1/(1 - a**2))*(1/(1 + 2*a**2 + a**4 - 4*a**2*cos(b)))*Q2
#Q2**-1
a, b, g0, g1, g2 = symbols('a, b, g0 g1 g2')
linsolve(Matrix(( [(1), (-2*a*cos(b)), (a**2), 1], [(-2*a*cos(b)), (1 + a**2), (0), 0], [(a**2), (-2*a*cos(b)), (1), 0])), (g0, g1, g2))
# Out:
# ⎧⎛                      2                                                      ↪
# ⎪⎜                   - a  - 1                                      -2⋅a⋅cos(b) ↪
# ⎨⎜──────────────────────────────────────────────, ──────────────────────────── ↪
# ⎪⎜ 6      4    2       4      2    2       2       6      4    2       4       ↪
# ⎩⎝a  - 4⋅a ⋅cos (b) + a  + 4⋅a ⋅cos (b) - a  - 1  a  - 4⋅a ⋅cos (b) + a  + 4⋅a ↪
#
# ↪                                  4      2    2       2            ⎞⎫
# ↪                                 a  - 4⋅a ⋅cos (b) + a             ⎟⎪
# ↪ ──────────────────, ──────────────────────────────────────────────⎟⎬
# ↪ 2    2       2       6      4    2       4      2    2       2    ⎟⎪
# ↪  ⋅cos (b) - a  - 1  a  - 4⋅a ⋅cos (b) + a  + 4⋅a ⋅cos (b) - a  - 1⎠⎭
